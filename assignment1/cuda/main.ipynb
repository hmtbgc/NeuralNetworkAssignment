# %%
from Dataset import Mnist
from Activate_function import ReLULayer, SoftmaxLayer, SigmoidLayer
from Model import FullyConnectedLayer
from Loss_function import CrossEntropyLoss
from Dataloader import DataLoader
from Optimizer import SGD
from Regularization import L2
import cupy as cp
import numpy as np
import os
from matplotlib import pyplot as plt
from tqdm import tqdm
from sklearn.manifold import TSNE

# %%
input_dim = 784
hidden_dim_tot = [128, 256]
output_dim = 10
batch_size = 128
Epoch = 30
lr_tot = [0.1, 0.01]
mini_lr = 0.0001
lam_tot = [0.01, 0.001]
train_rate = 0.8
valid_freq = 5
gamma = 0.99

# %%
dataset_root = "../data/mnist"
dataset = Mnist(dataset_root)
train_image, train_label, valid_image, valid_label, test_image, test_label = dataset.load(rate=train_rate)

# %%
train_dataloader = DataLoader(data=train_image, label=train_label, batch_size=batch_size)
valid_dataloader = DataLoader(data=valid_image, label=valid_label, batch_size=batch_size)
test_dataloader = DataLoader(data=test_image, label=test_label, batch_size=batch_size)

# %%
class Model():
    
    def __init__(self, input_dim, hidden_dim, output_dim):
        self.layer1 = FullyConnectedLayer(input_dim, hidden_dim)
        self.layer2 = ReLULayer()
        self.layer3 = FullyConnectedLayer(hidden_dim, output_dim)
        self.layer1.init_parameter()
        self.layer3.init_parameter()
        
    def forward(self, inputs):
        x = self.layer1.forward(inputs)
        x = self.layer2.forward(x)
        x = self.layer3.forward(x)
        return x
    
    def backward(self, Upstream_Gradient):
        gradient = self.layer3.backward(Upstream_Gradient)
        gradient = self.layer2.backward(gradient)
        gradient = self.layer1.backward(gradient)
        return gradient
    
    def get_params(self):
        params1 = self.layer1.get_params()
        params3 = self.layer3.get_params()
        return params1 + params3
    
    def get_grads(self):
        grads1 = self.layer1.get_grads()
        grads3 = self.layer3.get_grads()
        return grads1 + grads3
    
    def save_model(self, name):
        self.layer1.save_model(name=f"{name}_layer1")
        self.layer3.save_model(name=f"{name}_layer3")
    
    def load_model(self, path):
        self.layer1.load_model(path=f"{path}_layer1.npz")
        self.layer3.load_model(path=f"{path}_layer3.npz")
        
    def visualize_params(self, path, is_cupy=False):
        self.layer1.visualize_params(path=f"{path}/layer1.png", is_cupy=is_cupy)
        self.layer3.visualize_params(path=f"{path}/layer3.png", is_cupy=is_cupy)

# %%
loss_function = CrossEntropyLoss()

# %%
def eval(dataloader, model):
    acc = 0
    tot_number = 0
    loss = 0
    for data, label in dataloader.get_batch():
        data = data.reshape(-1, 28 * 28)
        tot_number += data.shape[0]
        model_forward_result = model.forward(data)
        loss += loss_function.forward(model_forward_result, label)
        prob = SoftmaxLayer().forward(model_forward_result)
        out = cp.argmax(prob, axis=1)
        acc += cp.sum(out == label)
    return acc / tot_number, loss

# %%
def run(hidden_dim, init_lr, lam):
    model = Model(input_dim, hidden_dim, output_dim)
    optimizer = SGD(init_lr)
    regularization = L2(lam)
    best_valid_acc = 0.0
    lr = init_lr
    epoch_loss = []
    epoch_valid_acc = []
    epoch_valid_loss = []
    valid_x = []
    for epoch in range(Epoch):
        batch_num = 0
        loss = 0
        for x_train, y_train in train_dataloader.get_batch():
            x_train = x_train.reshape(-1, 28 * 28)
            model_forward_result = model.forward(x_train)
            loss += loss_function.forward(model_forward_result, y_train)
            # print(f"epoch {epoch}, batch {batch_num}, loss: {loss:.4f}")
            batch_num += 1
            gradient = loss_function.backward()
            gradient = model.backward(gradient)
            # model.step(lr)
            params, grads = model.get_params(), model.get_grads()
            # for i in range(len(params)):
            #     print(f"params[{i}].shape: {params[i].shape}")
            #     print(f"grads[{i}].shape: {grads[i].shape}")
            regularization_grads = regularization.get_grads(model)
            for grad, regularization_grad in zip(grads, regularization_grads):
                grad += regularization_grad
            optimizer.step(params, grads)
            
        lr = lr * gamma
        lr = max(lr, mini_lr)
        optimizer.update_lr(lr)
        
        if (epoch > 0 and epoch % valid_freq == 0):
            valid_x.append(epoch)
            valid_acc, valid_loss = eval(valid_dataloader, model)
            epoch_valid_acc.append(valid_acc.get())
            epoch_valid_loss.append(valid_loss.get())
            if (valid_acc > best_valid_acc):
                best_valid_acc = valid_acc
                model.save_model(f"./model_params/Model_hid{hidden_dim}_lr{init_lr}_lambda{lam}")
        print(f"epoch {epoch}, loss: {loss:.4f}, best_valid_acc: {best_valid_acc: .4f}")
        epoch_loss.append(loss.get())
        
    return best_valid_acc, epoch_loss, epoch_valid_acc, epoch_valid_loss, valid_x

# %%
best_valid_acc = 0
best_hidden_dim, best_lr, best_lam = 0, 0, 0
epoch_loss_tot = []
epoch_valid_acc_tot = []
epoch_valid_loss_tot = []
label_tot = []
valid_x = None
for hidden_dim in hidden_dim_tot:
    for lr in lr_tot:
        for lam in lam_tot:
            valid_acc, epoch_loss, epoch_valid_acc, epoch_valid_loss, valid_x = run(hidden_dim, lr, lam)
            label = f"hid{hidden_dim}_lr{lr}_lambda{lam}"
            label_tot.append(label)
            epoch_loss_tot.append(epoch_loss)
            epoch_valid_acc_tot.append(epoch_valid_acc)
            epoch_valid_loss_tot.append(epoch_valid_loss)
            if (valid_acc > best_valid_acc):
                best_valid_acc = valid_acc
                best_hidden_dim, best_lr, best_lam = hidden_dim, lr, lam
print(f"best valid acc: {best_valid_acc:.4f}, hidden_dim: {hidden_dim}, lr: {best_lr}, lambda: {best_lam}")
# Out:
# epoch 0, loss: 1768.6789, best_valid_acc:  0.0000
# epoch 1, loss: 151.1843, best_valid_acc:  0.0000
# epoch 2, loss: 128.0016, best_valid_acc:  0.0000
# epoch 3, loss: 139.6942, best_valid_acc:  0.0000
# epoch 4, loss: 145.5632, best_valid_acc:  0.0000
# epoch 5, loss: 147.2555, best_valid_acc:  0.9091
# epoch 6, loss: 147.5549, best_valid_acc:  0.9091
# epoch 7, loss: 147.3649, best_valid_acc:  0.9091
# epoch 8, loss: 147.0069, best_valid_acc:  0.9091
# epoch 9, loss: 146.6374, best_valid_acc:  0.9091
# epoch 10, loss: 146.2780, best_valid_acc:  0.9091
# epoch 11, loss: 145.9506, best_valid_acc:  0.9091
# epoch 12, loss: 145.6189, best_valid_acc:  0.9091
# epoch 13, loss: 145.3239, best_valid_acc:  0.9091
# epoch 14, loss: 145.0577, best_valid_acc:  0.9091
# epoch 15, loss: 144.8094, best_valid_acc:  0.9109
# epoch 16, loss: 144.5662, best_valid_acc:  0.9109
# epoch 17, loss: 144.3386, best_valid_acc:  0.9109
# epoch 18, loss: 144.1252, best_valid_acc:  0.9109
# epoch 19, loss: 143.9223, best_valid_acc:  0.9109
# epoch 20, loss: 143.7271, best_valid_acc:  0.9125
# epoch 21, loss: 143.5402, best_valid_acc:  0.9125
# epoch 22, loss: 143.3568, best_valid_acc:  0.9125
# epoch 23, loss: 143.1806, best_valid_acc:  0.9125
# epoch 24, loss: 143.0068, best_valid_acc:  0.9125
# epoch 25, loss: 142.8427, best_valid_acc:  0.9139
# epoch 26, loss: 142.6894, best_valid_acc:  0.9139
# epoch 27, loss: 142.5424, best_valid_acc:  0.9139
# epoch 28, loss: 142.3986, best_valid_acc:  0.9139
# epoch 29, loss: 142.2560, best_valid_acc:  0.9139
# epoch 0, loss: 2355.6568, best_valid_acc:  0.0000
# epoch 1, loss: 602.0463, best_valid_acc:  0.0000
# epoch 2, loss: 342.6660, best_valid_acc:  0.0000
# epoch 3, loss: 226.4886, best_valid_acc:  0.0000
# epoch 4, loss: 165.0318, best_valid_acc:  0.0000
# epoch 5, loss: 129.3238, best_valid_acc:  0.9099
# epoch 6, loss: 107.4863, best_valid_acc:  0.9099
# epoch 7, loss: 93.4140, best_valid_acc:  0.9099
# epoch 8, loss: 83.8859, best_valid_acc:  0.9099
# epoch 9, loss: 77.1501, best_valid_acc:  0.9099
# epoch 10, loss: 72.1591, best_valid_acc:  0.9319
# epoch 11, loss: 68.2813, best_valid_acc:  0.9319
# epoch 12, loss: 65.1640, best_valid_acc:  0.9319
# epoch 13, loss: 62.5802, best_valid_acc:  0.9319
# epoch 14, loss: 60.4165, best_valid_acc:  0.9319
# epoch 15, loss: 58.5266, best_valid_acc:  0.9460
# epoch 16, loss: 56.9109, best_valid_acc:  0.9460
# epoch 17, loss: 55.5038, best_valid_acc:  0.9460
# epoch 18, loss: 54.2446, best_valid_acc:  0.9460
# epoch 19, loss: 53.1144, best_valid_acc:  0.9460
# epoch 20, loss: 52.0709, best_valid_acc:  0.9535
# epoch 21, loss: 51.1076, best_valid_acc:  0.9535
# epoch 22, loss: 50.2326, best_valid_acc:  0.9535
# epoch 23, loss: 49.4300, best_valid_acc:  0.9535
# epoch 24, loss: 48.6784, best_valid_acc:  0.9535
# epoch 25, loss: 47.9877, best_valid_acc:  0.9590
# epoch 26, loss: 47.3489, best_valid_acc:  0.9590
# epoch 27, loss: 46.7716, best_valid_acc:  0.9590
# epoch 28, loss: 46.2370, best_valid_acc:  0.9590
# epoch 29, loss: 45.7476, best_valid_acc:  0.9590
# epoch 0, loss: 7325.1839, best_valid_acc:  0.0000
# epoch 1, loss: 2336.6130, best_valid_acc:  0.0000
# epoch 2, loss: 1489.9149, best_valid_acc:  0.0000
# epoch 3, loss: 1064.9915, best_valid_acc:  0.0000
# epoch 4, loss: 802.5717, best_valid_acc:  0.0000
# epoch 5, loss: 623.7492, best_valid_acc:  0.8492
# epoch 6, loss: 495.8461, best_valid_acc:  0.8492
# epoch 7, loss: 401.6138, best_valid_acc:  0.8492
# epoch 8, loss: 330.7227, best_valid_acc:  0.8492
# epoch 9, loss: 276.5609, best_valid_acc:  0.8492
# epoch 10, loss: 234.8973, best_valid_acc:  0.8724
# epoch 11, loss: 202.7821, best_valid_acc:  0.8724
# epoch 12, loss: 178.1075, best_valid_acc:  0.8724
# epoch 13, loss: 159.3251, best_valid_acc:  0.8724
# epoch 14, loss: 145.2595, best_valid_acc:  0.8724
# epoch 15, loss: 134.9887, best_valid_acc:  0.8933
# epoch 16, loss: 127.7195, best_valid_acc:  0.8933
# epoch 17, loss: 122.8051, best_valid_acc:  0.8933
# epoch 18, loss: 119.7155, best_valid_acc:  0.8933
# epoch 19, loss: 118.0146, best_valid_acc:  0.8933
# epoch 20, loss: 117.3238, best_valid_acc:  0.9077
# epoch 21, loss: 117.3503, best_valid_acc:  0.9077
# epoch 22, loss: 117.8387, best_valid_acc:  0.9077
# epoch 23, loss: 118.6611, best_valid_acc:  0.9077
# epoch 24, loss: 119.7190, best_valid_acc:  0.9077
# epoch 25, loss: 120.9180, best_valid_acc:  0.9143
# epoch 26, loss: 122.1919, best_valid_acc:  0.9143
# epoch 27, loss: 123.5131, best_valid_acc:  0.9143
# epoch 28, loss: 124.8420, best_valid_acc:  0.9143
# epoch 29, loss: 126.1443, best_valid_acc:  0.9143
# epoch 0, loss: 7352.1579, best_valid_acc:  0.0000
# epoch 1, loss: 2474.2709, best_valid_acc:  0.0000
# epoch 2, loss: 1843.0603, best_valid_acc:  0.0000
# epoch 3, loss: 1515.5988, best_valid_acc:  0.0000
# epoch 4, loss: 1302.3744, best_valid_acc:  0.0000
# epoch 5, loss: 1148.0837, best_valid_acc:  0.8608
# epoch 6, loss: 1030.5899, best_valid_acc:  0.8608
# epoch 7, loss: 936.4531, best_valid_acc:  0.8608
# epoch 8, loss: 858.0911, best_valid_acc:  0.8608
# epoch 9, loss: 791.7754, best_valid_acc:  0.8608
# epoch 10, loss: 735.0020, best_valid_acc:  0.8782
# epoch 11, loss: 685.4688, best_valid_acc:  0.8782
# epoch 12, loss: 641.9218, best_valid_acc:  0.8782
# epoch 13, loss: 603.1841, best_valid_acc:  0.8782
# epoch 14, loss: 568.5029, best_valid_acc:  0.8782
# epoch 15, loss: 537.3650, best_valid_acc:  0.8852
# epoch 16, loss: 509.2233, best_valid_acc:  0.8852
# epoch 17, loss: 483.6351, best_valid_acc:  0.8852
# epoch 18, loss: 460.2142, best_valid_acc:  0.8852
# epoch 19, loss: 438.7007, best_valid_acc:  0.8852
# epoch 20, loss: 418.9116, best_valid_acc:  0.8918
# epoch 21, loss: 400.6302, best_valid_acc:  0.8918
# epoch 22, loss: 383.7037, best_valid_acc:  0.8918
# epoch 23, loss: 367.9960, best_valid_acc:  0.8918
# epoch 24, loss: 353.4120, best_valid_acc:  0.8918
# epoch 25, loss: 339.8578, best_valid_acc:  0.8969
# epoch 26, loss: 327.1947, best_valid_acc:  0.8969
# epoch 27, loss: 315.3392, best_valid_acc:  0.8969
# epoch 28, loss: 304.2295, best_valid_acc:  0.8969
# epoch 29, loss: 293.8172, best_valid_acc:  0.8969
# epoch 0, loss: 2480.4899, best_valid_acc:  0.0000
# epoch 1, loss: 168.5414, best_valid_acc:  0.0000
# epoch 2, loss: 104.9838, best_valid_acc:  0.0000
# epoch 3, loss: 130.4624, best_valid_acc:  0.0000
# epoch 4, loss: 144.7723, best_valid_acc:  0.0000
# epoch 5, loss: 149.5140, best_valid_acc:  0.9017
# epoch 6, loss: 150.7628, best_valid_acc:  0.9017
# epoch 7, loss: 150.9139, best_valid_acc:  0.9017
# epoch 8, loss: 150.6318, best_valid_acc:  0.9017
# epoch 9, loss: 150.1999, best_valid_acc:  0.9017
# epoch 10, loss: 149.7372, best_valid_acc:  0.9018
# epoch 11, loss: 149.2754, best_valid_acc:  0.9018
# epoch 12, loss: 148.8451, best_valid_acc:  0.9018
# epoch 13, loss: 148.4532, best_valid_acc:  0.9018
# epoch 14, loss: 148.0806, best_valid_acc:  0.9018
# epoch 15, loss: 147.7458, best_valid_acc:  0.9048
# epoch 16, loss: 147.4457, best_valid_acc:  0.9048
# epoch 17, loss: 147.1670, best_valid_acc:  0.9048
# epoch 18, loss: 146.9059, best_valid_acc:  0.9048
# epoch 19, loss: 146.6577, best_valid_acc:  0.9048
# epoch 20, loss: 146.4291, best_valid_acc:  0.9064
# epoch 21, loss: 146.2192, best_valid_acc:  0.9064
# epoch 22, loss: 146.0196, best_valid_acc:  0.9064
# epoch 23, loss: 145.8229, best_valid_acc:  0.9064
# epoch 24, loss: 145.6420, best_valid_acc:  0.9064
# epoch 25, loss: 145.4779, best_valid_acc:  0.9073
# epoch 26, loss: 145.3119, best_valid_acc:  0.9073
# epoch 27, loss: 145.1557, best_valid_acc:  0.9073
# epoch 28, loss: 145.0116, best_valid_acc:  0.9073
# epoch 29, loss: 144.8607, best_valid_acc:  0.9073
# epoch 0, loss: inf, best_valid_acc:  0.0000
# epoch 1, loss: 839.1362, best_valid_acc:  0.0000
# epoch 2, loss: 482.5827, best_valid_acc:  0.0000
# epoch 3, loss: 313.2115, best_valid_acc:  0.0000
# epoch 4, loss: 214.9919, best_valid_acc:  0.0000
# epoch 5, loss: 154.7496, best_valid_acc:  0.9235
# epoch 6, loss: 115.4289, best_valid_acc:  0.9235
# epoch 7, loss: 88.7832, best_valid_acc:  0.9235
# epoch 8, loss: 70.4436, best_valid_acc:  0.9235
# epoch 9, loss: 57.7367, best_valid_acc:  0.9235
# epoch 10, loss: 48.8903, best_valid_acc:  0.9377
# epoch 11, loss: 42.7718, best_valid_acc:  0.9377
# epoch 12, loss: 38.6084, best_valid_acc:  0.9377
# epoch 13, loss: 35.8685, best_valid_acc:  0.9377
# epoch 14, loss: 34.1443, best_valid_acc:  0.9377
# epoch 15, loss: 33.1460, best_valid_acc:  0.9503
# epoch 16, loss: 32.6544, best_valid_acc:  0.9503
# epoch 17, loss: 32.5377, best_valid_acc:  0.9503
# epoch 18, loss: 32.6802, best_valid_acc:  0.9503
# epoch 19, loss: 32.9808, best_valid_acc:  0.9503
# epoch 20, loss: 33.3627, best_valid_acc:  0.9592
# epoch 21, loss: 33.7780, best_valid_acc:  0.9592
# epoch 22, loss: 34.1821, best_valid_acc:  0.9592
# epoch 23, loss: 34.5888, best_valid_acc:  0.9592
# epoch 24, loss: 34.9840, best_valid_acc:  0.9592
# epoch 25, loss: 35.3475, best_valid_acc:  0.9636
# epoch 26, loss: 35.6878, best_valid_acc:  0.9636
# epoch 27, loss: 36.0059, best_valid_acc:  0.9636
# epoch 28, loss: 36.2977, best_valid_acc:  0.9636
# epoch 29, loss: 36.5793, best_valid_acc:  0.9636
# epoch 0, loss: 8640.0737, best_valid_acc:  0.0000
# epoch 1, loss: 2889.5092, best_valid_acc:  0.0000
# epoch 2, loss: 1913.5389, best_valid_acc:  0.0000
# epoch 3, loss: 1389.8078, best_valid_acc:  0.0000
# epoch 4, loss: 1053.2164, best_valid_acc:  0.0000
# epoch 5, loss: 819.4290, best_valid_acc:  0.8703
# epoch 6, loss: 648.9008, best_valid_acc:  0.8703
# epoch 7, loss: 521.5463, best_valid_acc:  0.8703
# epoch 8, loss: 424.5799, best_valid_acc:  0.8703
# epoch 9, loss: 349.6940, best_valid_acc:  0.8703
# epoch 10, loss: 291.1990, best_valid_acc:  0.8921
# epoch 11, loss: 245.2097, best_valid_acc:  0.8921
# epoch 12, loss: 208.9165, best_valid_acc:  0.8921
# epoch 13, loss: 180.2321, best_valid_acc:  0.8921
# epoch 14, loss: 157.6117, best_valid_acc:  0.8921
# epoch 15, loss: 139.9062, best_valid_acc:  0.9065
# epoch 16, loss: 126.1907, best_valid_acc:  0.9065
# epoch 17, loss: 115.7479, best_valid_acc:  0.9065
# epoch 18, loss: 108.0130, best_valid_acc:  0.9065
# epoch 19, loss: 102.5054, best_valid_acc:  0.9065
# epoch 20, loss: 98.8334, best_valid_acc:  0.9191
# epoch 21, loss: 96.6608, best_valid_acc:  0.9191
# epoch 22, loss: 95.6778, best_valid_acc:  0.9191
# epoch 23, loss: 95.6387, best_valid_acc:  0.9191
# epoch 24, loss: 96.3175, best_valid_acc:  0.9191
# epoch 25, loss: 97.5199, best_valid_acc:  0.9267
# epoch 26, loss: 99.1037, best_valid_acc:  0.9267
# epoch 27, loss: 100.9396, best_valid_acc:  0.9267
# epoch 28, loss: 102.9305, best_valid_acc:  0.9267
# epoch 29, loss: 105.0123, best_valid_acc:  0.9267
# epoch 0, loss: 8714.8609, best_valid_acc:  0.0000
# epoch 1, loss: 3276.4707, best_valid_acc:  0.0000
# epoch 2, loss: 2486.6714, best_valid_acc:  0.0000
# epoch 3, loss: 2062.6000, best_valid_acc:  0.0000
# epoch 4, loss: 1782.1865, best_valid_acc:  0.0000
# epoch 5, loss: 1576.6261, best_valid_acc:  0.8762
# epoch 6, loss: 1416.6920, best_valid_acc:  0.8762
# epoch 7, loss: 1288.0410, best_valid_acc:  0.8762
# epoch 8, loss: 1180.5536, best_valid_acc:  0.8762
# epoch 9, loss: 1088.9700, best_valid_acc:  0.8762
# epoch 10, loss: 1009.1383, best_valid_acc:  0.8888
# epoch 11, loss: 939.2543, best_valid_acc:  0.8888
# epoch 12, loss: 877.8404, best_valid_acc:  0.8888
# epoch 13, loss: 823.5014, best_valid_acc:  0.8888
# epoch 14, loss: 774.7770, best_valid_acc:  0.8888
# epoch 15, loss: 730.5915, best_valid_acc:  0.8968
# epoch 16, loss: 690.6786, best_valid_acc:  0.8968
# epoch 17, loss: 654.7040, best_valid_acc:  0.8968
# epoch 18, loss: 621.9934, best_valid_acc:  0.8968
# epoch 19, loss: 592.0175, best_valid_acc:  0.8968
# epoch 20, loss: 564.4626, best_valid_acc:  0.9016
# epoch 21, loss: 539.0151, best_valid_acc:  0.9016
# epoch 22, loss: 515.4596, best_valid_acc:  0.9016
# epoch 23, loss: 493.5492, best_valid_acc:  0.9016
# epoch 24, loss: 473.1516, best_valid_acc:  0.9016
# epoch 25, loss: 454.1353, best_valid_acc:  0.9063
# epoch 26, loss: 436.3723, best_valid_acc:  0.9063
# epoch 27, loss: 419.7506, best_valid_acc:  0.9063
# epoch 28, loss: 404.1343, best_valid_acc:  0.9063
# epoch 29, loss: 389.4461, best_valid_acc:  0.9063
# best valid acc: 0.9636, hidden_dim: 256, lr: 0.1, lambda: 0.001

# %%
plt.figure(1)
for i, epoch_loss in enumerate(epoch_loss_tot):
    plt.plot(np.arange(len(epoch_loss)), epoch_loss, label=label_tot[i])
plt.xlabel("epoch")
plt.ylabel("loss/epoch")
plt.title("loss curve")
plt.legend(loc="best") 
plt.savefig("train_loss_curve.png", dpi=300)

plt.figure(2)
for i, epoch_valid_acc in enumerate(epoch_valid_acc_tot):
    plt.plot(valid_x, epoch_valid_acc, label=label_tot[i])
plt.xticks(valid_x, valid_x)
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.title("validation accuracy curve")
plt.legend(loc="best") 
plt.savefig("acc_curve.png", dpi=300)

plt.figure(3)
for i, epoch_valid_loss in enumerate(epoch_valid_loss_tot):
    plt.plot(valid_x, epoch_valid_loss, label=label_tot[i])
plt.xticks(valid_x, valid_x)
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("validation loss curve")
plt.legend(loc="best") 
plt.savefig("valid_loss_curve.png", dpi=300)

# %%
def reduction_dimension(X):
    tsne = TSNE(n_components=2, random_state=0)
    X_tsne = tsne.fit_transform(X)
    return X_tsne

# %%
print("testing...")
test_model = Model(0, 0, 0)
test_model.load_model(f"./model_params/Model_hid{best_hidden_dim}_lr{best_lr}_lambda{best_lam}")
test_acc, _ = eval(test_dataloader, test_model)
print(f"test acc: {test_acc:.4f}")
plt.figure(1)
plt.imshow(test_model.layer1.W.get(), cmap='coolwarm')
plt.colorbar()
plt.savefig("./parameter_visualize/layer1.png", dpi=300)
plt.figure(2)
plt.imshow(test_model.layer3.W.get(), cmap='coolwarm')
plt.colorbar()
plt.savefig("./parameter_visualize/layer3.png", dpi=300)
layer1_reduction = reduction_dimension(test_model.layer1.W.get())
layer3_reduction = reduction_dimension(test_model.layer3.W.get())
plt.figure(3)
plt.scatter(layer1_reduction[:, 0], layer1_reduction[:, 1])
plt.title("first layer's weights in 2 dimension plane")
plt.savefig("./parameter_visualize/layer1_reduction.png", dpi=300)
plt.figure(4)
plt.scatter(layer3_reduction[:, 0], layer3_reduction[:, 1])
plt.title("second layer's weights in 2 dimension plane")
plt.savefig("./parameter_visualize/layer3_reduction.png", dpi=300)
# Out:
# testing...
# test acc: 0.9642
